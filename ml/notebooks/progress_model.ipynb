# %% [markdown]
# # Progress Model (v1)
#
# Minimalny pipeline: generowanie danych, budowa cech, trening, ewaluacja i zapis modelu.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parents[0]
sys.path.append(str(ROOT))

from src.generate_data import main as generate_data
from src.features import build_features
from src.train import train_model
from src.evaluate import evaluate_model
import pandas as pd

# %%
generate_data()

# %%
df = pd.read_csv(ROOT / 'data' / 'checkins.csv')
X, y, features = build_features(df)
X.head()

# %%
metrics = train_model()
metrics

# %%
evaluate_model()
